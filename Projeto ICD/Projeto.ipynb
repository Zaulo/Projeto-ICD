# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('tweets.csv')

# %%
df
# Out:
#                               user_name    user_location  \
# 0                   Alphonso.KessleruVr              NaN
# 1                           Jon carrick              NaN
# 2                     We Are Video Game       California
# 3                            god dammit              NaN
# 4                     We Are Video Game       California
# ...                                 ...              ...
# 22713                            Millie  New Jersey, USA
# 22714                                𝐊𝐙              NaN
# 22715                            Phraze    Miami Florida
# 22716  Official Page of MonkeyViral.com   Globe & Beyond
# 22717                        MikieSnaxx    Charlotte NC
#
#                                         user_description  \
# 0                                                    NaN
# 1      I love a nice day at the beach \n#iamlokkingat...
# 2                                    We Are Video Games!
# ...

# %%
df_2 = pd.read_csv('genius_hip_hop_lyrics.csv', encoding='ISO-8859-1')

# %%
df_2
# Out:
#       id      candidate                     song              artist  \
# 0      1  Mike Huckabee          None Shall Pass          Aesop Rock
# 1      2  Mike Huckabee                Wellstone           Soul Khan
# 2      3       Jeb Bush                      Awe          Dez & Nobs
# 3      4       Jeb Bush                The Truth            Diabolic
# 4      5       Jeb Bush                Money Man         Gorilla Zoe
# ..   ...            ...                      ...                 ...
# 372  374   Donald Trump               On the Way          Young Thug
# 373  375   Donald Trump                Digest It               Tiara
# 374  376   Donald Trump        Constantly Hating          Young Thug
# 375  377   Donald Trump  FDT (Fuck Donald Trump)  YG & Nipsey Hussle
# 376  378   Donald Trump          It's Goin' Down            Yung Joc
#
#     sentiment      theme  album_release_date  \
# 0     neutral        NaN                2011
# ...

# %%
df.describe().astype(int)
# Out:
#        user_followers  user_friends  user_favourites
# count           22718         22718            22718
# mean            16017          1465            18312
# std            287042          7981            61923
# min                 0             0                0
# 25%                43            90              257
# 50%               245           360             2212
# 75%              1208          1218            11903
# max          18446310        581608          1240341

# %%
df_2.describe().astype(int)
# Out:
#         id  album_release_date
# count  377                 377
# mean   189                2008
# std    109                   6
# min      1                1989
# 25%     95                2005
# 50%    190                2011
# 75%    284                2014
# max    378                2016

# %%
df.boxplot(column=['user_followers', 'user_friends', 'user_favourites'])
# Out:
# <Axes: >

# %%
plt.show()

# %%
df_2.boxplot(column=['album_release_date'])
# Out:
# <Axes: >

# %%
data = df_2['album_release_date']

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12680b43b10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x12680b40a90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x12680b43090>],
#  'medians': [<matplotlib.lines.Line2D at 0x12680b427d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12680b2bb50>],
#  'means': []}

# %%
plt.title('boxplot data dos albuns')
# Out:
# Text(0.5, 1.0, 'boxplot data dos albuns')

# %%
plt.show()
